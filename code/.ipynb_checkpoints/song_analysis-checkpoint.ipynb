# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(pd.read_csv('../resources/data.csv'))
df.head()
# Out:
#    Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 0           0        0.0102         0.833       204600   0.434
# 1           1        0.1990         0.743       326933   0.359
# 2           2        0.0344         0.838       185707   0.412
# 3           3        0.6040         0.494       199413   0.338
# 4           4        0.1800         0.678       392893   0.561
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.021900    2    0.1650    -8.795     1       0.4310  150.062
# 1          0.006110    1    0.1370   -10.401     1       0.0794  160.083
# 2          0.000234    2    0.1590    -7.148     1       0.2890   75.044
# 3          0.510000    5    0.0922   -15.236     1       0.0261   86.468
# 4          0.512000    5    0.4390   -11.648     0       0.0694  174.004
#
#    time_signature  valence  target      song_title            artist
# 0             4.0    0.286       1        Mask Off            Future
# ...

# %% [markdown]
# # 50 most danceable artists on Spotify

# %%
df.groupby('artist')['danceability'].mean().sort_values(ascending=False).head(15)
# Out:
# artist
# Ben Remember         0.984
# Justin Timberlake    0.967
# Blaqstarr            0.962
# Vanilla Ice          0.959
# Selena Gomez         0.950
# StaRR Lyfe           0.947
# Tumble Tots          0.941
# Missy Elliott        0.932
# Finatticz            0.931
# Lunice               0.931
# Claptone             0.930
# Los Del Rio          0.927
# Bill Withers         0.912
# Lil Reese            0.908
# Celeda               0.907
# Name: danceability, dtype: float64

# %%
ax1 = df.plot.scatter(x='acousticness',
                      y='danceability',
                      figsize=(12,8))

# %%
ax1 = df.plot.scatter(x='loudness',
                      y='danceability',
                      figsize=(12,8))

# %%
df.groupby('time_signature')['danceability'].mean().plot.bar(figsize=(12,8))
